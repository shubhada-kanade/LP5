# %%
# Step 1: Import Libraries
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# %%
# Step 3: Display Dataset Shape
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
print("Training Data Shape :", x_train.shape)
print("Testing Data Shape  :", x_test.shape)
# Out:
# Training Data Shape : (60000, 28, 28)
# Testing Data Shape  : (10000, 28, 28)

# %%
# Step 4: Normalize the Data
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
# Step 5: Class Labels
class_names = [
    'T-shirt/top',
    'Trouser',
    'Pullover',
    'Dress',
    'Coat',
    'Sandal',
    'Shirt',
    'Sneaker',
    'Bag',
    'Ankle boot'
]

# %%
# Step 6: Display Sample Images
plt.figure(figsize=(10,10))

for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(x_train[i], cmap='gray')
    plt.title(class_names[y_train[i]])
    plt.axis('off')

plt.show()

# %%
# Step 7: Build Deep Neural Network Model
model = Sequential([
    Flatten(input_shape=(28,28)),
    
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    
    Dense(10, activation='softmax')
])
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Step 8: Compile Model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Step 9: Train Model
history = model.fit(
    x_train,
    y_train,
    epochs=10,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.8196 - loss: 0.5124 - val_accuracy: 0.8583 - val_loss: 0.4027
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.8639 - loss: 0.3789 - val_accuracy: 0.8628 - val_loss: 0.3702
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 6ms/step - accuracy: 0.8751 - loss: 0.3431 - val_accuracy: 0.8736 - val_loss: 0.3505
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.8834 - loss: 0.3160 - val_accuracy: 0.8779 - val_loss: 0.3371
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.8890 - loss: 0.2987 - val_accuracy: 0.8729 - val_loss: 0.3559
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - accuracy: 0.8935 - loss: 0.2847 - val_accuracy: 0.8810 - val_loss: 0.3233
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 28s 13ms/step - accuracy: 0.8984 - loss: 0.2735 - val_accuracy: 0.8771 - val_loss: 0.3361
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - accuracy: 0.9022 - loss: 0.2606 - val_accuracy: 0.8872 - val_loss: 0.3171
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - accuracy: 0.9051 - loss: 0.2518 - val_accuracy: 0.8880 - val_loss: 0.3170
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 36s 11ms/step - accuracy: 0.9097 - loss: 0.2407 - val_accuracy: 0.8907 - val_loss: 0.3234

# %%
# Step 10: Evaluate Model
test_loss, test_accuracy = model.evaluate(x_test, y_test)

print("\nTest Accuracy :", test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8838 - loss: 0.3514
#
# Test Accuracy : 0.8838000297546387

# %%
# Step 11: Predict on Test Data
predictions = model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step

# %%
# Step 12: Show Prediction Example
index = 5

plt.imshow(x_test[index], cmap='gray')
plt.title("Predicted : " + class_names[np.argmax(predictions[index])])
plt.axis('off')
plt.show()

print("Actual Label    :", class_names[y_test[index]])
print("Predicted Label :", class_names[np.argmax(predictions[index])])
# Out:
# Actual Label    : Trouser
# Predicted Label : Trouser

# %%
# Step 13: Plot Accuracy Graph
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.legend(['Training Accuracy', 'Validation Accuracy'])

plt.show()

# %%
# Step 14: Plot Loss Graph
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.legend(['Training Loss', 'Validation Loss'])

plt.show()
